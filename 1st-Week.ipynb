# %% [markdown]
# # Week 1 Code Files

# %% [markdown]
# ## 1. Linux Commands Practice (linux_practice.sh)

# %%
#!/bin/bash
# Task 2: Linux Commands Practice

echo "=== Basic Linux Commands Practice ==="

# Navigation and file operations
echo "1. Current directory:"
pwd

echo "2. Listing files:"
ls -la

echo "3. Creating test directory:"
mkdir test_dir
cd test_dir

echo "4. Creating test files:"
touch file1.txt file2.txt
echo "Hello World" > file1.txt
cat file1.txt

echo "5. Copying file:"
cp file1.txt file1_copy.txt

echo "6. Moving file:"
mv file2.txt file2_renamed.txt

echo "7. Removing file:"
rm file1_copy.txt

echo "8. Checking file permissions:"
ls -l

echo "9. Changing permissions:"
chmod 755 file1.txt

echo "10. Process listing:"
ps aux | head -5

cd ..
echo "11. Removing directory:"
rm -r test_dir

echo "Linux commands practice completed!"
# Out:
#   Cell In[1], line 4
#     echo "=== Basic Linux Commands Practice ==="
#          ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## 2. Python Basic Exercises

# %%
# Task 3: Basic Addition
print("=== Task 3: Basic Addition ===")

num1 = 1.5
num2 = 6.3

# Add two numbers
sum = num1 + num2

# Display the sum
print('The sum of {0} and {1} is {2}'.format(num1, num2, sum))
# Out:
# === Task 3: Basic Addition ===
# The sum of 1.5 and 6.3 is 7.8

# %%
# Task 4: User Input Addition
print("=== Task 4: User Input Addition ===")

# Store input numbers
num1 = input('Enter first number: ')
num2 = input('Enter second number: ')

# Add two numbers
sum = float(num1) + float(num2)

# Display the sum
print('The sum of {0} and {1} is {2}'.format(num1, num2, sum))
# Out:
# === Task 4: User Input Addition ===
# Enter first number:  67
# Enter second number:  6
# The sum of 67 and 6 is 73.0

# %%
# Task 5: Square Root
print("=== Task 5: Square Root ===")

# Fixed value
num = 8

# To take input from user (uncomment below)
# num = float(input('Enter a number: '))

num_sqrt = num ** 0.5
print('The square root of %0.3f is %0.3f' % (num, num_sqrt))
# Out:
# === Task 5: Square Root ===
# The square root of 8.000 is 2.828

# %%
# Task 6: Complex Square Root
print("=== Task 6: Complex Square Root ===")

import cmath

num = 1+2j

# To take input from user (uncomment below)
# num = eval(input('Enter a number: '))

num_sqrt = cmath.sqrt(num)
print('The square root of {0} is {1:0.3f}+{2:0.3f}j'.format(
    num, num_sqrt.real, num_sqrt.imag))
# Out:
# === Task 6: Complex Square Root ===
# The square root of (1+2j) is 1.272+0.786j

# %%
# Task 7: Temperature Conversion
print("=== Task 7: Temperature Conversion ===")

celsius = 37.5

# calculate fahrenheit
fahrenheit = (celsius * 1.8) + 32
print('%0.1f degree Celsius is equal to %0.1f degree Fahrenheit' % 
      (celsius, fahrenheit))
# Out:
# === Task 7: Temperature Conversion ===
# 37.5 degree Celsius is equal to 99.5 degree Fahrenheit

# %%
# Task 8: Triangle Area
print("=== Task 8: Triangle Area ===")

a = 5
b = 6
c = 7

# Uncomment below to take inputs from the user
# a = float(input('Enter first side: '))
# b = float(input('Enter second side: '))
# c = float(input('Enter third side: '))

# calculate the semi-perimeter
s = (a + b + c) / 2

# calculate the area
area = (s*(s-a)*(s-b)*(s-c)) ** 0.5
print('The area of the triangle is %0.2f' % area)
# Out:
# === Task 8: Triangle Area ===
# The area of the triangle is 14.70

# %%
# Task 9: Quadratic Equation
print("=== Task 9: Quadratic Equation ===")

import cmath

a = 1
b = 5
c = 6

# calculate the discriminant
d = (b**2) - (4*a*c)

# find two solutions
sol1 = (-b - cmath.sqrt(d)) / (2*a)
sol2 = (-b + cmath.sqrt(d)) / (2*a)

print('The solutions are {0} and {1}'.format(sol1, sol2))
# Out:
# === Task 9: Quadratic Equation ===
# The solutions are (-3+0j) and (-2+0j)

# %%
# Task 10: Kilometers to Miles
print("=== Task 10: Kilometers to Miles ===")

# Taking kilometers input from the user
kilometers = float(input("Enter value in kilometers: "))

# conversion factor
conv_fac = 0.621371

# calculate miles
miles = kilometers * conv_fac
print('%0.2f kilometers is equal to %0.2f miles' % (kilometers, miles))
# Out:
# === Task 10: Kilometers to Miles ===
# Enter value in kilometers:  6
# 6.00 kilometers is equal to 3.73 miles

# %%
# Task 11: If Statement
print("=== Task 11: If Statement ===")

i = 10
if (i > 15):
    print("10 is less than 15")
print("I am Not in if")
# Out:
# === Task 11: If Statement ===
# I am Not in if

# %%
# Task 12: If-Else Statement
print("=== Task 12: If-Else Statement ===")

i = 20
if (i < 15):
    print("i is smaller than 15")
    print("i'm in if Block")
else:
    print("i is greater than 15")
    print("i'm in else Block")
print("i'm not in if and not in else Block")
# Out:
# === Task 12: If-Else Statement ===
# i is greater than 15
# i'm in else Block
# i'm not in if and not in else Block

# %%
# Task 13: Nested If Statement
print("=== Task 13: Nested If Statement ===")

i = 10
if (i == 10):
    # First if statement
    if (i < 15):
        print("i is smaller than 15")
    # Nested - if statement
    if (i < 12):
        print("i is smaller than 12 too")
else:
    print("i is greater than 15")
# Out:
# === Task 13: Nested If Statement ===
# i is smaller than 15
# i is smaller than 12 too

# %%
# Task 14: Elif Statement
print("=== Task 14: Elif Statement ===")

i = 20
if (i == 10):
    print("i is 10")
elif (i == 15):
    print("i is 15")
elif (i == 20):
    print("i is 20")
else:
    print("i is not present")
# Out:
# === Task 14: Elif Statement ===
# i is 20

# %%
# Additional basic exercises for Tasks 15-19
print("=== Additional Basic Exercises ===")

# For loop example
print("For loop example:")
for i in range(5):
    print(f"Number: {i}")

# While loop example
print("\nWhile loop example:")
count = 0
while count < 3:
    print(f"Count: {count}")
    count += 1

# Break statement example
print("\nBreak statement example:")
for i in range(10):
    if i == 5:
        break
    print(i)

# Continue statement example
print("\nContinue statement example:")
for i in range(5):
    if i == 2:
        continue
    print(i)
# Out:
# === Additional Basic Exercises ===
# For loop example:
# Number: 0
# Number: 1
# Number: 2
# Number: 3
# Number: 4
#
# While loop example:
# Count: 0
# Count: 1
# Count: 2
#
# Break statement example:
# 0
# 1
# 2
# 3
# 4
#
# Continue statement example:
# 0
# 1
# 3
# 4
